# %%
import pandas as pd

# %%
# Load the Excel file into a DataFrame
file_path = "..\dataset\Online Retail.xlsx"   

df = pd.read_excel(file_path)

# Check the first few rows
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
# Basic dataset overview
df.shape
# Out:
# (541909, 8)

# %%
# Column names and data types
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  datetime64[ns]
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 33.1+ MB

# %%
# Descriptive statistics for numerical columns
numeric_cols = ["Quantity", "UnitPrice"]

df[numeric_cols].describe()
# Out:
#             Quantity      UnitPrice
# count  541909.000000  541909.000000
# mean        9.552250       4.611114
# std       218.081158      96.759853
# min    -80995.000000  -11062.060000
# 25%         1.000000       1.250000
# 50%         3.000000       2.080000
# 75%        10.000000       4.130000
# max     80995.000000   38970.000000

# %% [markdown]
# In above statistics we can see that in the Quantity column we have negative values present. That shouldn't be the case as that column description says "the quantities of each product (item) per transaction".
# Same is the case with Unit Price column. Need to identify this thing and tackle it smartly.

# %%
# Mode values for categorical columns
categorical_cols = ["StockCode", "CustomerID", "Country"]

df[categorical_cols].mode()
# Out:
#   StockCode  CustomerID         Country
# 0    85123A     17841.0  United Kingdom

# %% [markdown]
# From above statistics we can understand which values appeared maximum time in the data. Through this we know that which StockCode is getting sold the most, which customer is ordering the maximum stock and which country is buying the most stock.

# %%
# Negative Quantity (likely returns)
neg_quantity_df = df[df["Quantity"] < 0]

# Negative UnitPrice (less common, might be data issues)
neg_price_df = df[df["UnitPrice"] < 0]

# %%
neg_quantity_df.head()
# Out:
#     InvoiceNo StockCode                       Description  Quantity  \
# 141   C536379         D                          Discount        -1
# 154   C536383    35004C   SET OF 3 COLOURED  FLYING DUCKS        -1
# 235   C536391     22556    PLASTERS IN TIN CIRCUS PARADE        -12
# 236   C536391     21984  PACK OF 12 PINK PAISLEY TISSUES        -24
# 237   C536391     21983  PACK OF 12 BLUE PAISLEY TISSUES        -24
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# 141 2010-12-01 09:41:00      27.50     14527.0  United Kingdom
# 154 2010-12-01 09:49:00       4.65     15311.0  United Kingdom
# 235 2010-12-01 10:24:00       1.65     17548.0  United Kingdom
# 236 2010-12-01 10:24:00       0.29     17548.0  United Kingdom
# 237 2010-12-01 10:24:00       0.29     17548.0  United Kingdom

# %%
neg_price_df.head()
# Out:
#        InvoiceNo StockCode      Description  Quantity         InvoiceDate  \
# 299983   A563186         B  Adjust bad debt         1 2011-08-12 14:51:00
# 299984   A563187         B  Adjust bad debt         1 2011-08-12 14:52:00
#
#         UnitPrice  CustomerID         Country
# 299983  -11062.06         NaN  United Kingdom
# 299984  -11062.06         NaN  United Kingdom

# %%
df.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
# Calculate percentage of null values in specific columns

null_percentage = (
    df[["CustomerID", "Description"]]
    .isnull()
    .mean() * 100
)

# print(null_percentage)

# Create a summary table for null values

null_summary = pd.DataFrame({
    "Null Count": df[["CustomerID", "Description"]].isnull().sum(),
    "Null Percentage": (df[["CustomerID", "Description"]].isnull().mean() * 100)
})

null_summary
# Out:
#              Null Count  Null Percentage
# CustomerID       135080        24.926694
# Description        1454         0.268311

# %%
# Rows where CustomerID is null

customerid_null_df = df[df["CustomerID"].isnull()]

# %%
display(customerid_null_df)
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 1443      536544     21773  DECORATIVE ROSE BATHROOM BOTTLE         1
# 1444      536544     21774  DECORATIVE CATS BATHROOM BOTTLE         2
# 1445      536544     21786               POLKADOT RAIN HAT          4
# 1446      536544     21787            RAIN PONCHO RETROSPOT         2
# 1447      536544     21790               VINTAGE SNAP CARDS         9
# ...          ...       ...                              ...       ...
# 541536    581498    85099B          JUMBO BAG RED RETROSPOT         5
# 541537    581498    85099C   JUMBO  BAG BAROQUE BLACK WHITE         4
# 541538    581498     85150    LADIES & GENTLEMEN METAL SIGN         1
# 541539    581498     85174                S/4 CACTI CANDLES         1
# 541540    581498       DOT                   DOTCOM POSTAGE         1
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
# Rows where both CustomerID and Description are null

null_customer_description_df = df[
    (df["CustomerID"].isnull()) & 
    (df["Description"].isnull())
]

display(null_customer_description_df)
# Out:
#        InvoiceNo StockCode Description  Quantity         InvoiceDate  \
# 622       536414     22139         NaN        56 2010-12-01 11:52:00
# 1970      536545     21134         NaN         1 2010-12-01 14:32:00
# 1971      536546     22145         NaN         1 2010-12-01 14:33:00
# 1972      536547     37509         NaN         1 2010-12-01 14:33:00
# 1987      536549    85226A         NaN         1 2010-12-01 14:34:00
# ...          ...       ...         ...       ...                 ...
# 535322    581199     84581         NaN        -2 2011-12-07 18:26:00
# 535326    581203     23406         NaN        15 2011-12-07 18:31:00
# 535332    581209     21620         NaN         6 2011-12-07 18:35:00
# 536981    581234     72817         NaN        27 2011-12-08 10:33:00
# 538554    581408     85175         NaN        20 2011-12-08 14:06:00
#
#         UnitPrice  CustomerID         Country
# 622           0.0         NaN  United Kingdom
# ...

# %%
# Remove rows where BOTH CustomerID and Description are null

df = df[
    ~(
        (df["CustomerID"].isnull()) & 
        (df["Description"].isnull())
    )
]

# %%
df.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description         0
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     133626
# Country             0
# dtype: int64

# %%
# Find rows where CustomerID is null
null_customer_df = df[df["CustomerID"].isnull()].copy()

# Columns to compare (excluding CustomerID)
compare_cols = [col for col in df.columns if col != "CustomerID"]

# Find rows where CustomerID exists
non_null_customer_df = df[df["CustomerID"].notnull()].copy()

# Merge to identify matching rows
duplicate_like_nulls = null_customer_df.merge(
    non_null_customer_df,
    on=compare_cols,
    how="inner"
)

# Display matching rows
duplicate_like_nulls.head()
# Out:
# Empty DataFrame
# Columns: [InvoiceNo, StockCode, Description, Quantity, InvoiceDate, UnitPrice, CustomerID_x, Country, CustomerID_y]
# Index: []

# %%
duplicate_like_nulls.shape[0]
# Out:
# 0

# %%
# Rows where CustomerID is null
# AND Quantity = 0 OR UnitPrice = 0

null_customer_zero_df = df[
    (df["CustomerID"].isnull()) &
    (
        (df["Quantity"] <= 0) |
        (df["UnitPrice"] <= 0)
    )
]

null_customer_zero_df
# Out:
#        InvoiceNo StockCode                   Description  Quantity  \
# 6391      536941     22734                        amazon        20
# 6392      536942     22139                        amazon        15
# 7313      537032     21275                             ?       -30
# 11502    C537251     22429    ENAMEL MEASURING JUG CREAM        -2
# 11503    C537251     22620   4 TRADITIONAL SPINNING TOPS        -8
# ...          ...       ...                           ...       ...
# 535336    581213     22576                         check       -30
# 536908    581226     23090                       missing      -338
# 538504    581406    46000M  POLYESTER FILLER PAD 45x45cm       240
# 538505    581406    46000S  POLYESTER FILLER PAD 40x40cm       300
# 538919    581422     23169                       smashed      -235
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# 6391   2010-12-03 12:08:00       0.00         NaN  United Kingdom
# ...

# %% [markdown]
# # Dirty data inspection

# %% [markdown]
# **InvoiceNo** have following
# a 6-digit integral number uniquely assigned to each transaction. If this code starts with letter 'c', it indicates a cancellation
#
# So if the any entry is less than 6 digit or if it is more than 6 digit and does not have C in starting of it. That data I want to see.

# %%
# Convert to string first
df["InvoiceNo"] = df["InvoiceNo"].astype(str)

# Condition for valid InvoiceNo
valid_invoice = (
    df["InvoiceNo"].str.match(r'^\d{6}$') |      # exactly 6 digits
    df["InvoiceNo"].str.match(r'^C\d{6}$')       # C followed by 6 digits
)

# Invalid InvoiceNo rows
invalid_invoice_df = df[~valid_invoice]

invalid_invoice_df
# Out:
#        InvoiceNo StockCode      Description  Quantity         InvoiceDate  \
# 299982   A563185         B  Adjust bad debt         1 2011-08-12 14:50:00
# 299983   A563186         B  Adjust bad debt         1 2011-08-12 14:51:00
# 299984   A563187         B  Adjust bad debt         1 2011-08-12 14:52:00
#
#         UnitPrice  CustomerID         Country
# 299982   11062.06         NaN  United Kingdom
# 299983  -11062.06         NaN  United Kingdom
# 299984  -11062.06         NaN  United Kingdom

# %%
# Convert StockCode to string
df["StockCode"] = df["StockCode"].astype(str)

# Valid StockCode condition
valid_stockcode = df["StockCode"].str.match(r'^\d{5}$')

# Invalid StockCode rows
invalid_stockcode_df = df[~valid_stockcode]

invalid_stockcode_df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# 45        536370      POST                              POSTAGE         3
# ...          ...       ...                                  ...       ...
# 541778    581578    84997C      CHILDRENS CUTLERY POLKADOT BLUE         8
# 541809    581579    85099C       JUMBO  BAG BAROQUE BLACK WHITE        10
# 541838    581580    84993A            75 GREEN PETIT FOUR CASES         2
# 541844    581580    85049A        TRADITIONAL CHRISTMAS RIBBONS         1
# 541853    581580    85049E            SCANDINAVIAN REDS RIBBONS         2
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
df[df["StockCode"] == "84993A"]

# %%
# Convert StockCode to string
df["StockCode"] = df["StockCode"].astype(str)

# Rows where StockCode length is less than 5
short_stockcode_df = df[df["StockCode"].str.len() < 5]

short_stockcode_df
# Out:
#        InvoiceNo StockCode     Description  Quantity         InvoiceDate  \
# 45        536370      POST         POSTAGE         3 2010-12-01 08:45:00
# 141      C536379         D        Discount        -1 2010-12-01 09:41:00
# 386       536403      POST         POSTAGE         1 2010-12-01 11:27:00
# 1123      536527      POST         POSTAGE         1 2010-12-01 13:04:00
# 1423      536540        C2        CARRIAGE         1 2010-12-01 14:05:00
# ...          ...       ...             ...       ...                 ...
# 541540    581498       DOT  DOTCOM POSTAGE         1 2011-12-09 10:26:00
# 541541   C581499         M          Manual        -1 2011-12-09 10:28:00
# 541730    581570      POST         POSTAGE         1 2011-12-09 11:59:00
# 541767    581574      POST         POSTAGE         2 2011-12-09 12:09:00
# 541768    581578      POST         POSTAGE         3 2011-12-09 12:16:00
#
#         UnitPrice  CustomerID         Country
# ...

# %%
# Distinct StockCode values with length less than 5
short_stockcode_df["StockCode"].unique()
# Out:
# array(['POST', 'D', 'C2', 'DOT', 'M', 'S', 'm', 'PADS', 'B', 'CRUK'],
#       dtype=object)

# %%
# View rows for each suspicious StockCode separately

post_df = df[df["StockCode"] == "POST"]
d_df = df[df["StockCode"] == "D"]
c2_df = df[df["StockCode"] == "C2"]
dot_df = df[df["StockCode"] == "DOT"]
m_df = df[df["StockCode"] == "M"]
s_df = df[df["StockCode"] == "S"]
small_m_df = df[df["StockCode"] == "m"]
pads_df = df[df["StockCode"] == "PADS"]
b_df = df[df["StockCode"] == "B"]
cruk_df = df[df["StockCode"] == "CRUK"]

# %%
cruk_df.head()
# Out:
#        InvoiceNo StockCode      Description  Quantity         InvoiceDate  \
# 317508   C564763      CRUK  CRUK Commission        -1 2011-08-30 10:49:00
# 324023   C565382      CRUK  CRUK Commission        -1 2011-09-02 15:45:00
# 333779   C566216      CRUK  CRUK Commission        -1 2011-09-09 15:17:00
# 338848   C566565      CRUK  CRUK Commission        -1 2011-09-13 12:32:00
# 351003   C567655      CRUK  CRUK Commission        -1 2011-09-21 14:40:00
#
#         UnitPrice  CustomerID         Country
# 317508       1.60     14096.0  United Kingdom
# 324023      13.01     14096.0  United Kingdom
# 333779      15.96     14096.0  United Kingdom
# 338848      52.24     14096.0  United Kingdom
# 351003     608.66     14096.0  United Kingdom

# %%
pads_df.head()
# Out:
#        InvoiceNo StockCode                 Description  Quantity  \
# 157195    550193      PADS  PADS TO MATCH ALL CUSHIONS         1
# 279045    561226      PADS  PADS TO MATCH ALL CUSHIONS         1
# 358655    568158      PADS  PADS TO MATCH ALL CUSHIONS         1
# 359871    568200      PADS  PADS TO MATCH ALL CUSHIONS         1
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# 157195 2011-04-15 09:27:00      0.001     13952.0  United Kingdom
# 279045 2011-07-26 10:13:00      0.001     15618.0  United Kingdom
# 358655 2011-09-25 12:22:00      0.000     16133.0  United Kingdom
# 359871 2011-09-25 14:58:00      0.001     16198.0  United Kingdom

# %%
small_m_df.head()
# Out:
#       InvoiceNo StockCode Description  Quantity         InvoiceDate  \
# 40383    539736         m      Manual         1 2010-12-21 15:18:00
#
#        UnitPrice  CustomerID         Country
# 40383       2.55         NaN  United Kingdom

# %%
s_df.head()
# Out:
#       InvoiceNo StockCode Description  Quantity         InvoiceDate  \
# 14436   C537581         S     SAMPLES        -1 2010-12-07 12:03:00
# 14437   C537581         S     SAMPLES        -1 2010-12-07 12:03:00
# 96680   C544580         S     SAMPLES        -1 2011-02-21 14:25:00
# 96681   C544580         S     SAMPLES        -1 2011-02-21 14:25:00
# 96682   C544580         S     SAMPLES        -1 2011-02-21 14:25:00
#
#        UnitPrice  CustomerID         Country
# 14436      12.95         NaN  United Kingdom
# 14437      52.00         NaN  United Kingdom
# 96680       5.74         NaN  United Kingdom
# 96681      11.08         NaN  United Kingdom
# 96682       5.79         NaN  United Kingdom

# %%
m_df.head()
# Out:
#      InvoiceNo StockCode Description  Quantity         InvoiceDate  UnitPrice  \
# 2239    536569         M      Manual         1 2010-12-01 15:35:00       1.25
# 2250    536569         M      Manual         1 2010-12-01 15:35:00      18.95
# 5684    536865         M      Manual         1 2010-12-03 11:28:00       2.55
# 6798    536981         M      Manual         2 2010-12-03 14:26:00       0.85
# 7976    537077         M      Manual        12 2010-12-05 11:59:00       0.42
#
#       CustomerID         Country
# 2239     16274.0  United Kingdom
# 2250     16274.0  United Kingdom
# 5684         NaN  United Kingdom
# 6798     14723.0  United Kingdom
# 7976     17062.0  United Kingdom

# %%
dot_df.head()
# Out:
#      InvoiceNo StockCode     Description  Quantity         InvoiceDate  \
# 1814    536544       DOT  DOTCOM POSTAGE         1 2010-12-01 14:32:00
# 3041    536592       DOT  DOTCOM POSTAGE         1 2010-12-01 17:06:00
# 5450    536862       DOT  DOTCOM POSTAGE         1 2010-12-03 11:13:00
# 5545    536864       DOT  DOTCOM POSTAGE         1 2010-12-03 11:27:00
# 5685    536865       DOT  DOTCOM POSTAGE         1 2010-12-03 11:28:00
#
#       UnitPrice  CustomerID         Country
# 1814     569.77         NaN  United Kingdom
# 3041     607.49         NaN  United Kingdom
# 5450     254.43         NaN  United Kingdom
# 5545     121.06         NaN  United Kingdom
# 5685     498.47         NaN  United Kingdom

# %%
post_df.head()
# Out:
#      InvoiceNo StockCode Description  Quantity         InvoiceDate  UnitPrice  \
# 45      536370      POST     POSTAGE         3 2010-12-01 08:45:00       18.0
# 386     536403      POST     POSTAGE         1 2010-12-01 11:27:00       15.0
# 1123    536527      POST     POSTAGE         1 2010-12-01 13:04:00       18.0
# 5073    536840      POST     POSTAGE         1 2010-12-02 18:27:00       18.0
# 5258    536852      POST     POSTAGE         1 2010-12-03 09:51:00       18.0
#
#       CustomerID      Country
# 45       12583.0       France
# 386      12791.0  Netherlands
# 1123     12662.0      Germany
# 5073     12738.0      Germany
# 5258     12686.0       France

# %%
b_df.head()
# Out:
#        InvoiceNo StockCode      Description  Quantity         InvoiceDate  \
# 299982   A563185         B  Adjust bad debt         1 2011-08-12 14:50:00
# 299983   A563186         B  Adjust bad debt         1 2011-08-12 14:51:00
# 299984   A563187         B  Adjust bad debt         1 2011-08-12 14:52:00
#
#         UnitPrice  CustomerID         Country
# 299982   11062.06         NaN  United Kingdom
# 299983  -11062.06         NaN  United Kingdom
# 299984  -11062.06         NaN  United Kingdom

# %%
c2_df.head()
# Out:
#       InvoiceNo StockCode Description  Quantity         InvoiceDate  \
# 1423     536540        C2    CARRIAGE         1 2010-12-01 14:05:00
# 12119    537368        C2    CARRIAGE         1 2010-12-06 12:40:00
# 12452    537378        C2    CARRIAGE         1 2010-12-06 13:06:00
# 19975    537963        C2    CARRIAGE         1 2010-12-09 11:30:00
# 20016    538002        C2    CARRIAGE         1 2010-12-09 11:48:00
#
#        UnitPrice  CustomerID          Country
# 1423        50.0     14911.0             EIRE
# 12119       50.0     14911.0             EIRE
# 12452       50.0     14911.0             EIRE
# 19975       50.0     13369.0   United Kingdom
# 20016       50.0     14932.0  Channel Islands

# %%
# Convert InvoiceDate to datetime

df["InvoiceDate"] = pd.to_datetime(
    df["InvoiceDate"],
    errors="coerce"
)

# %%
# Rows with invalid InvoiceDate

invalid_date_df = df[df["InvoiceDate"].isnull()]

invalid_date_df
# Out:
# Empty DataFrame
# Columns: [InvoiceNo, StockCode, Description, Quantity, InvoiceDate, UnitPrice, CustomerID, Country]
# Index: []

# %% [markdown]
# No invalid dates are present according to the syntax.

# %%
# Define valid date range

start_date = pd.Timestamp("2010-11-30")
end_date = pd.Timestamp("2011-12-10")

# Find transactions outside range

outside_range_df = df[
    (df["InvoiceDate"] <= start_date) |
    (df["InvoiceDate"] >= end_date)
]

outside_range_df
# Out:
# Empty DataFrame
# Columns: [InvoiceNo, StockCode, Description, Quantity, InvoiceDate, UnitPrice, CustomerID, Country]
# Index: []

# %%
df["Country"].unique()
# Out:
# array(['United Kingdom', 'France', 'Australia', 'Netherlands', 'Germany',
#        'Norway', 'EIRE', 'Switzerland', 'Spain', 'Poland', 'Portugal',
#        'Italy', 'Belgium', 'Lithuania', 'Japan', 'Iceland',
#        'Channel Islands', 'Denmark', 'Cyprus', 'Sweden', 'Austria',
#        'Israel', 'Finland', 'Bahrain', 'Greece', 'Hong Kong', 'Singapore',
#        'Lebanon', 'United Arab Emirates', 'Saudi Arabia',
#        'Czech Republic', 'Canada', 'Unspecified', 'Brazil', 'USA',
#        'European Community', 'Malta', 'South Africa'], dtype=object)

# %%
# Replace RSA with South Africa

df["Country"] = df["Country"].replace("RSA", "South Africa")

# %%
# Export cleaned dataset to Excel for Power BI

df.to_excel("final_cleaned_dataset.xlsx", index=False)
