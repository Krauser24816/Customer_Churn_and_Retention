# %%
import pandas as pd

# %%
# Load the Excel file into a DataFrame
file_path = "..\dataset\Online Retail.xlsx"   

df = pd.read_excel(file_path)

# Check the first few rows
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
# Basic dataset overview
df.shape
# Out:
# (541909, 8)

# %%
# Column names and data types
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  datetime64[ns]
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(4)
# memory usage: 33.1+ MB

# %%
# Descriptive statistics for numerical columns
numeric_cols = ["Quantity", "UnitPrice"]

df[numeric_cols].describe()
# Out:
#             Quantity      UnitPrice
# count  541909.000000  541909.000000
# mean        9.552250       4.611114
# std       218.081158      96.759853
# min    -80995.000000  -11062.060000
# 25%         1.000000       1.250000
# 50%         3.000000       2.080000
# 75%        10.000000       4.130000
# max     80995.000000   38970.000000

# %% [markdown]
# In above statistics we can see that in the Quantity column we have negative values present. That shouldn't be the case as that column description says "the quantities of each product (item) per transaction".
# Same is the case with Unit Price column. Need to identify this thing and tackle it smartly.

# %%
# Mode values for categorical columns
categorical_cols = ["StockCode", "CustomerID", "Country"]

df[categorical_cols].mode()
# Out:
#   StockCode  CustomerID         Country
# 0    85123A     17841.0  United Kingdom

# %% [markdown]
# From above statistics we can understand which values appeared maximum time in the data. Through this we know that which StockCode is getting sold the most, which customer is ordering the maximum stock and which country is buying the most stock.

# %%
# Negative Quantity (likely returns)
neg_quantity_df = df[df["Quantity"] < 0]

# Negative UnitPrice (less common, might be data issues)
neg_price_df = df[df["UnitPrice"] < 0]

# %%
neg_quantity_df.head()
# Out:
#     InvoiceNo StockCode                       Description  Quantity  \
# 141   C536379         D                          Discount        -1
# 154   C536383    35004C   SET OF 3 COLOURED  FLYING DUCKS        -1
# 235   C536391     22556    PLASTERS IN TIN CIRCUS PARADE        -12
# 236   C536391     21984  PACK OF 12 PINK PAISLEY TISSUES        -24
# 237   C536391     21983  PACK OF 12 BLUE PAISLEY TISSUES        -24
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# 141 2010-12-01 09:41:00      27.50     14527.0  United Kingdom
# 154 2010-12-01 09:49:00       4.65     15311.0  United Kingdom
# 235 2010-12-01 10:24:00       1.65     17548.0  United Kingdom
# 236 2010-12-01 10:24:00       0.29     17548.0  United Kingdom
# 237 2010-12-01 10:24:00       0.29     17548.0  United Kingdom

# %%
neg_price_df.head()
# Out:
#        InvoiceNo StockCode      Description  Quantity         InvoiceDate  \
# 299983   A563186         B  Adjust bad debt         1 2011-08-12 14:51:00
# 299984   A563187         B  Adjust bad debt         1 2011-08-12 14:52:00
#
#         UnitPrice  CustomerID         Country
# 299983  -11062.06         NaN  United Kingdom
# 299984  -11062.06         NaN  United Kingdom

# %%
df.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
# Calculate percentage of null values in specific columns

null_percentage = (
    df[["CustomerID", "Description"]]
    .isnull()
    .mean() * 100
)

# print(null_percentage)

# Create a summary table for null values

null_summary = pd.DataFrame({
    "Null Count": df[["CustomerID", "Description"]].isnull().sum(),
    "Null Percentage": (df[["CustomerID", "Description"]].isnull().mean() * 100)
})

null_summary
# Out:
#              Null Count  Null Percentage
# CustomerID       135080        24.926694
# Description        1454         0.268311

# %%
# Rows where CustomerID is null

customerid_null_df = df[df["CustomerID"].isnull()]

# %%
display(customerid_null_df)
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 1443      536544     21773  DECORATIVE ROSE BATHROOM BOTTLE         1
# 1444      536544     21774  DECORATIVE CATS BATHROOM BOTTLE         2
# 1445      536544     21786               POLKADOT RAIN HAT          4
# 1446      536544     21787            RAIN PONCHO RETROSPOT         2
# 1447      536544     21790               VINTAGE SNAP CARDS         9
# ...          ...       ...                              ...       ...
# 541536    581498    85099B          JUMBO BAG RED RETROSPOT         5
# 541537    581498    85099C   JUMBO  BAG BAROQUE BLACK WHITE         4
# 541538    581498     85150    LADIES & GENTLEMEN METAL SIGN         1
# 541539    581498     85174                S/4 CACTI CANDLES         1
# 541540    581498       DOT                   DOTCOM POSTAGE         1
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# 1443   2010-12-01 14:32:00       2.51         NaN  United Kingdom
# 1444   2010-12-01 14:32:00       2.51         NaN  United Kingdom
# 1445   2010-12-01 14:32:00       0.85         NaN  United Kingdom
# 1446   2010-12-01 14:32:00       1.66         NaN  United Kingdom
# 1447   2010-12-01 14:32:00       1.66         NaN  United Kingdom
# ...                    ...        ...         ...             ...
# 541536 2011-12-09 10:26:00       4.13         NaN  United Kingdom
# 541537 2011-12-09 10:26:00       4.13         NaN  United Kingdom
# 541538 2011-12-09 10:26:00       4.96         NaN  United Kingdom
# 541539 2011-12-09 10:26:00      10.79         NaN  United Kingdom
# 541540 2011-12-09 10:26:00    1714.17         NaN  United Kingdom
#
# [133626 rows x 8 columns]

# %%
# Rows where both CustomerID and Description are null

null_customer_description_df = df[
    (df["CustomerID"].isnull()) & 
    (df["Description"].isnull())
]

display(null_customer_description_df)
# Out:
#        InvoiceNo StockCode Description  Quantity         InvoiceDate  \
# 622       536414     22139         NaN        56 2010-12-01 11:52:00
# 1970      536545     21134         NaN         1 2010-12-01 14:32:00
# 1971      536546     22145         NaN         1 2010-12-01 14:33:00
# 1972      536547     37509         NaN         1 2010-12-01 14:33:00
# 1987      536549    85226A         NaN         1 2010-12-01 14:34:00
# ...          ...       ...         ...       ...                 ...
# 535322    581199     84581         NaN        -2 2011-12-07 18:26:00
# 535326    581203     23406         NaN        15 2011-12-07 18:31:00
# 535332    581209     21620         NaN         6 2011-12-07 18:35:00
# 536981    581234     72817         NaN        27 2011-12-08 10:33:00
# 538554    581408     85175         NaN        20 2011-12-08 14:06:00
#
#         UnitPrice  CustomerID         Country
# 622           0.0         NaN  United Kingdom
# 1970          0.0         NaN  United Kingdom
# 1971          0.0         NaN  United Kingdom
# 1972          0.0         NaN  United Kingdom
# 1987          0.0         NaN  United Kingdom
# ...           ...         ...             ...
# 535322        0.0         NaN  United Kingdom
# 535326        0.0         NaN  United Kingdom
# 535332        0.0         NaN  United Kingdom
# 536981        0.0         NaN  United Kingdom
# 538554        0.0         NaN  United Kingdom
#
# [1454 rows x 8 columns]

# %%
# Remove rows where BOTH CustomerID and Description are null

df = df[
    ~(
        (df["CustomerID"].isnull()) & 
        (df["Description"].isnull())
    )
]

# %%
df.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description         0
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     133626
# Country             0
# dtype: int64

# %%
# Find rows where CustomerID is null
null_customer_df = df[df["CustomerID"].isnull()].copy()

# Columns to compare (excluding CustomerID)
compare_cols = [col for col in df.columns if col != "CustomerID"]

# Find rows where CustomerID exists
non_null_customer_df = df[df["CustomerID"].notnull()].copy()

# Merge to identify matching rows
duplicate_like_nulls = null_customer_df.merge(
    non_null_customer_df,
    on=compare_cols,
    how="inner"
)

# Display matching rows
duplicate_like_nulls.head()
# Out:
# Empty DataFrame
# Columns: [InvoiceNo, StockCode, Description, Quantity, InvoiceDate, UnitPrice, CustomerID_x, Country, CustomerID_y]
# Index: []

# %%
duplicate_like_nulls.shape[0]
# Out:
# 0

# %%
# Rows where CustomerID is null
# AND Quantity = 0 OR UnitPrice = 0

null_customer_zero_df = df[
    (df["CustomerID"].isnull()) &
    (
        (df["Quantity"] <= 0) |
        (df["UnitPrice"] <= 0)
    )
]

null_customer_zero_df
# Out:
#        InvoiceNo StockCode                   Description  Quantity  \
# 6391      536941     22734                        amazon        20
# 6392      536942     22139                        amazon        15
# 7313      537032     21275                             ?       -30
# 11502    C537251     22429    ENAMEL MEASURING JUG CREAM        -2
# 11503    C537251     22620   4 TRADITIONAL SPINNING TOPS        -8
# ...          ...       ...                           ...       ...
# 535336    581213     22576                         check       -30
# 536908    581226     23090                       missing      -338
# 538504    581406    46000M  POLYESTER FILLER PAD 45x45cm       240
# 538505    581406    46000S  POLYESTER FILLER PAD 40x40cm       300
# 538919    581422     23169                       smashed      -235
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# 6391   2010-12-03 12:08:00       0.00         NaN  United Kingdom
# 6392   2010-12-03 12:08:00       0.00         NaN  United Kingdom
# 7313   2010-12-03 16:50:00       0.00         NaN  United Kingdom
# 11502  2010-12-06 10:45:00       4.25         NaN  United Kingdom
# 11503  2010-12-06 10:45:00       1.25         NaN  United Kingdom
# ...                    ...        ...         ...             ...
# 535336 2011-12-07 18:38:00       0.00         NaN  United Kingdom
# 536908 2011-12-08 09:56:00       0.00         NaN  United Kingdom
# 538504 2011-12-08 13:58:00       0.00         NaN  United Kingdom
# 538505 2011-12-08 13:58:00       0.00         NaN  United Kingdom
# 538919 2011-12-08 15:24:00       0.00         NaN  United Kingdom
#
# [1406 rows x 8 columns]

# %% [markdown]
# # Dirty data inspection

# %% [markdown]
# **InvoiceNo** have following
# a 6-digit integral number uniquely assigned to each transaction. If this code starts with letter 'c', it indicates a cancellation
#
# So if the any entry is less than 6 digit or if it is more than 6 digit and does not have C in starting of it. That data I want to see.

# %%
# Convert to string first
df["InvoiceNo"] = df["InvoiceNo"].astype(str)

# Condition for valid InvoiceNo
valid_invoice = (
    df["InvoiceNo"].str.match(r'^\d{6}$') |      # exactly 6 digits
    df["InvoiceNo"].str.match(r'^C\d{6}$')       # C followed by 6 digits
)

# Invalid InvoiceNo rows
invalid_invoice_df = df[~valid_invoice]

invalid_invoice_df
# Out:
#        InvoiceNo StockCode      Description  Quantity         InvoiceDate  \
# 299982   A563185         B  Adjust bad debt         1 2011-08-12 14:50:00
# 299983   A563186         B  Adjust bad debt         1 2011-08-12 14:51:00
# 299984   A563187         B  Adjust bad debt         1 2011-08-12 14:52:00
#
#         UnitPrice  CustomerID         Country
# 299982   11062.06         NaN  United Kingdom
# 299983  -11062.06         NaN  United Kingdom
# 299984  -11062.06         NaN  United Kingdom

# %%
# Convert StockCode to string
df["StockCode"] = df["StockCode"].astype(str)

# Valid StockCode condition
valid_stockcode = df["StockCode"].str.match(r'^\d{5}$')

# Invalid StockCode rows
invalid_stockcode_df = df[~valid_stockcode]

invalid_stockcode_df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# 45        536370      POST                              POSTAGE         3
# ...          ...       ...                                  ...       ...
# 541778    581578    84997C      CHILDRENS CUTLERY POLKADOT BLUE         8
# 541809    581579    85099C       JUMBO  BAG BAROQUE BLACK WHITE        10
# 541838    581580    84993A            75 GREEN PETIT FOUR CASES         2
# 541844    581580    85049A        TRADITIONAL CHRISTMAS RIBBONS         1
# 541853    581580    85049E            SCANDINAVIAN REDS RIBBONS         2
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# 0      2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 2      2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 45     2010-12-01 08:45:00      18.00     12583.0          France
# ...                    ...        ...         ...             ...
# 541778 2011-12-09 12:16:00       4.15     12713.0         Germany
# 541809 2011-12-09 12:19:00       1.79     17581.0  United Kingdom
# 541838 2011-12-09 12:20:00       0.42     12748.0  United Kingdom
# 541844 2011-12-09 12:20:00       1.25     12748.0  United Kingdom
# 541853 2011-12-09 12:20:00       1.25     12748.0  United Kingdom
#
# [54463 rows x 8 columns]

# %%
df[df["StockCode"] == "84993A"]
# Out:
#        InvoiceNo StockCode                Description  Quantity  \
# 5691      536874    84993A  75 GREEN PETIT FOUR CASES         1
# 18483     537823    84993A  75 GREEN PETIT FOUR CASES         2
# 19735     537888    84993A  75 GREEN PETIT FOUR CASES        24
# 25856     538418    84993A  75 GREEN PETIT FOUR CASES         2
# 28729     538655    84993A  75 GREEN PETIT FOUR CASES         6
# 36419     539451    84993A  75 GREEN PETIT FOUR CASES         1
# 43291     540026    84993A  75 GREEN PETIT FOUR CASES         1
# 43600     540098    84993A  75 GREEN PETIT FOUR CASES         1
# 44044     540154    84993A  75 GREEN PETIT FOUR CASES         1
# 48723     540473    84993A  75 GREEN PETIT FOUR CASES         3
# 54571     540957    84993A  75 GREEN PETIT FOUR CASES         2
# 55549     540995    84993A  75 GREEN PETIT FOUR CASES         1
# 68600     541870    84993A  75 GREEN PETIT FOUR CASES         1
# 74324     542420    84993A  75 GREEN PETIT FOUR CASES         2
# 87063     543631    84993A  75 GREEN PETIT FOUR CASES         2
# 97180     544599    84993A  75 GREEN PETIT FOUR CASES         1
# 117902    546412    84993A  75 GREEN PETIT FOUR CASES         2
# 139063    548267    84993A  75 GREEN PETIT FOUR CASES        24
